# %% [markdown]
# # AOC performance
# De puzzels in AOC zijn ingedeeld in verschillende segmenten. Om bij te houden hoe goed de code werkt houd ik met deze classes en functies de prestaties van mijn oplossingen bij.
